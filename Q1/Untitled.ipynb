# %%
import math
import numpy as np
from skimage.io import imread, imsave
from PIL import Image
import matplotlib.pyplot as plt

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import math
from PopularitySampling import PopularitySampling 
from sklearn.neighbors import KDTree

# %%
import numpy as np
rng = np.random.RandomState(0)
X = rng.random_sample((30, 3))
r = np.linspace(0, 1, 5)
tree = KDTree(X)                
tree

# %%
tree

# %%
popularity_obj = PopularitySampling()

# %%
input_img = cv2.imread('data/input/loin.jpg')

# %%
k_popularity_algo= 512
topk_colors= popularity_obj.quantize_image(input_img,k_popularity_algo)

# %%
# Out:
# [(21, 16, 15),
#  (22, 17, 16),
#  (23, 18, 17),
#  (22, 16, 17),
#  (24, 16, 16),
#  (23, 15, 15),
#  (23, 17, 18),
#  (24, 19, 18),
#  (24, 18, 19),
#  (25, 17, 17),
#  (22, 17, 18),
#  (20, 16, 15),
#  (23, 18, 19),
#  (20, 15, 14),
#  (21, 15, 16),
#  (32, 29, 24),
#  (33, 30, 25),
#  (25, 19, 20),
#  (223, 220, 242),
#  (34, 31, 26),
#  (21, 17, 16),
#  (25, 20, 19),
#  (21, 16, 13),
#  (21, 16, 17),
#  (227, 225, 245),
#  (224, 222, 242),
#  (234, 231, 247),
#  (235, 232, 248),
#  (24, 19, 20),
#  (41, 58, 55),
#  (35, 32, 27),
#  (26, 18, 18),
#  (31, 28, 23),
#  (236, 233, 249),
#  (226, 223, 245),
#  (27, 19, 19),
#  (23, 19, 18),
#  (232, 228, 247),
#  (229, 224, 245),
#  (233, 230, 246),
#  (228, 226, 246),
#  (225, 222, 244),
#  (42, 59, 56),
#  (227, 223, 242),
#  (234, 230, 249),
#  (226, 224, 244),
#  (237, 234, 249),
#  (231, 227, 246),
#  (219, 213, 236),
#  (219, 213, 238),
#  (230, 226, 245),
#  (20, 15, 16),
#  (232, 229, 245),
#  (24, 16, 17),
# ...

# %%
input_img_matplot = cv2.cvtColor(input_img,cv2.COLOR_BGR2RGB)
plt.imshow(input_img_matplot)
plt.show()
