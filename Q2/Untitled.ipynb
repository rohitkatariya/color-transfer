# %%
import cv2
# %matplotlib inline
#The line above is necesary to show Matplotlib's plots inside a Jupyter Notebook
from matplotlib import pyplot as plt
import os
import random
import pandas as pd
import numpy as np
import math

# %%
from skimage import exposure

# %%
dir_color_transfer = 'data/color_transfer_image'
dir_input = dir_color_transfer+'/input/'
dir_output = dir_color_transfer+'/output/'

# %%
os.listdir(dir_input)
# Out:
# ['bw_watermellon.jpg',
#  'color_trees.jpg',
#  'color_house.jpg',
#  'color_road.jpg',
#  'bw_road2.jpg',
#  'color_road2.jpg',
#  'bw_road.jpg',
#  'bw_trees2.jpg',
#  'color_watermellon2.jpg',
#  'color_watermellon.jpg',
#  'bw_watermellon2.jpg',
#  'color_trees2.jpg',
#  'color_mountain.jpg',
#  'bw_house.jpg',
#  'bw_trees.jpg',
#  'bw_agri.jpg',
#  'mountain2.jpg',
#  'color_road3.jpg',
#  'bw_road3.jpg',
#  'color_agri.jpg']

# %%
image_names_dict = [['color_'+z.split('_')[1],'bw_'+z.split('_')[1]] for z in os.listdir(dir_input) if z.startswith('bw')]
image_names_dict
# Out:
# [['color_watermellon.jpg', 'bw_watermellon.jpg'],
#  ['color_road2.jpg', 'bw_road2.jpg'],
#  ['color_road.jpg', 'bw_road.jpg'],
#  ['color_trees2.jpg', 'bw_trees2.jpg'],
#  ['color_watermellon2.jpg', 'bw_watermellon2.jpg'],
#  ['color_house.jpg', 'bw_house.jpg'],
#  ['color_trees.jpg', 'bw_trees.jpg'],
#  ['color_agri.jpg', 'bw_agri.jpg'],
#  ['color_road3.jpg', 'bw_road3.jpg']]

# %%
orig_image =cv2.imread(dir_input+'ja.png',0)
cv2.imwrite(dir_output+'bw_agri.jpg', orig_image)
# Out:
# True

# %%
orig_image = cv2.cvtColor(orig_image, cv2.COLOR_BGR2RGB)
# cv2.imwrite(dir_output+'bw_road3.jpg', orig_image)

# %%
plt.imshow(orig_image)
plt.show()
